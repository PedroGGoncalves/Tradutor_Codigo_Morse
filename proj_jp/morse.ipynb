# %% [markdown]
# # Tradutor do Código Morse

# %% [markdown]
# Primeiramente, iremos decidir o que será feito

# %%
op = int(input("(1)Traduzir Código Morse ou (2)Codificar em Código Morse: "))
if(op==1):
    print("Bora Traduzir ")
else:
    print("Bora Codificar ")
print(op)
# Out:
# (1)Traduzir Código Morse ou (2)Codificar em Código Morse: 1
# Bora Traduzir
# 1

# %%
#https://www.invertexto.com/codigo-morse - Site para conferir entradas

# %% [markdown]
# Agora, iremos passar a frase que será traduzida

# %%
frase=input("Digite a frase: ")
print("A frase é '"+ frase+ "'")
frase=frase.lower()
# Out:
# Digite a frase: . / . ..- / ... . .. / --.- ..- . / - . -- / -- --- -- . -. - --- ... / --- -. -.. . / .--. .- .-. . -.-. . / --.- ..- . / .- / ...- .. -.. .- / ...- .- .. / - . / . ... -- .- --. .- .-. / -.-. --- -- / . ... ... . / .--. . ... --- / -- .- ... / .- / -.. --- .-. / -. .- --- / .--. --- -.. . / - . / -.. . .. -..- .- .-. / -.. . / .-.. . -- -... .-. .- .-. / ... --- .... / --.- ..- .- -. -.. --- / . ... - .- -- --- ... / -. --- / -.-. .... .- --- / . .... / --.- ..- . / .--. --- -.. . -- --- ... / .-.. . ...- .- -. - .- .-.
# ...

# %% [markdown]
# Aqui abaixo vemos a tabela usada para a conversão

# %% [markdown]
# ![morse.png](attachment:morse.png)

# %%
cont=0
if(op==1):
    lst=frase.split()
    teste= frase.split()
    for i in teste:
        if (i==".-"):
            print("a")
            lst[cont]="a"
        elif (i=="-..."):
            print("b")
            lst[cont]="b"
        elif (i=="-.-."):
            print("c")
            lst[cont]="c"
        elif (i=="-.."):
            print("d")
            lst[cont]="d"
        elif (i=="."):
            print("e")
            lst[cont]="e"
        elif (i=="..-."):
            print("f")
            lst[cont]="f"
        elif (i=="--."):
            print("g")
            lst[cont]="g"
        elif (i=="...."):
            print("h")
            lst[cont]="h"
        elif (i==".."):
            print("i")
            lst[cont]="i"
        elif (i==".---"):
            print("j")
            lst[cont]="j"
        elif (i=="-.-"):
            print("k")
            lst[cont]="k"
        elif (i==".-.."):
            print("l")
            lst[cont]="l"
        elif (i=="--"):
            print("m")
            lst[cont]="m"
        elif (i=="-."):
            print("n")
            lst[cont]="n"
        elif (i=="---"):
            print("o")
            lst[cont]="o"
        elif (i==".--."):
            print("p")
            lst[cont]="p"
        elif (i=="--.-"):
            print("q")
            lst[cont]="q"
        elif (i==".-."):
            print("r")
            lst[cont]="r"
        elif (i=="..."):
            print("s")
            lst[cont]="s"
        elif (i=="-"):
            print("t")
            lst[cont]="t"
        elif (i=="..-"):
            print("u")
            lst[cont]="u"
        elif (i=="...-"):
            print("v")
            lst[cont]="v"
        elif (i==".--"):
            print("w")
            lst[cont]="w"
        elif (i=="-..-"):
            print("x")
            lst[cont]="x"
        elif (i=="-.--"):
            print("y")
            lst[cont]="y"
        elif (i=="--.."):
            print("z")
            lst[cont]="z"
        elif (i==".----"):
            print("1")
            lst[cont]="1"
        elif (i=="..---"):
            print("2")
            lst[cont]="2"
        elif (i=="...--"):
            print("3")
            lst[cont]="3"
        elif (i=="....-"):
            print("4")
            lst[cont]="4"
        elif (i=="....."):
            print("5")
            lst[cont]="5"
        elif (i=="-...."):
            print("6")
            lst[cont]="6"
        elif (i=="--..."):
            print("7")
            lst[cont]="7"
        elif (i=="---.."):
            print("8")
            lst[cont]="8"
        elif (i=="----."):
            print("9")
            lst[cont]="9"
        elif (i=="-----"):
            print("0")
            lst[cont]="0"
        elif (i=="/"):
            print(" ")
            lst[cont]=" "
        cont=cont+1
elif(op==2):
    lst=list(frase)+list(frase)
    teste= list(frase)
    for i in teste:
        if (i=="a"):
            print(".-")
            lst[cont]=".-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="b"):
            print("-...")
            lst[cont]="-..."
            cont=cont+1
            lst[cont]=" "
        elif (i=="c"):
            print("-.-.")
            lst[cont]="-.-."
            cont=cont+1
            lst[cont]=" "
        elif (i=="d"):
            print("-..")
            lst[cont]="-.."
            cont=cont+1
            lst[cont]=" "
        elif (i=="e"):
            print(".")
            lst[cont]="."
            cont=cont+1
            lst[cont]=" "
        elif (i=="f"):
            print("..-.")
            lst[cont]="..-."
            cont=cont+1
            lst[cont]=" "
        elif (i=="g"):
            print("--.")
            lst[cont]="--."
            cont=cont+1
            lst[cont]=" "
        elif (i=="h"):
            print("....")
            lst[cont]="...."
            cont=cont+1
            lst[cont]=" "
        elif (i=="i"):
            print("..")
            lst[cont]=".."
            cont=cont+1
            lst[cont]=" "
        elif (i=="j"):
            print(".---")
            lst[cont]=".---"
            cont=cont+1
            lst[cont]=" "
        elif (i=="k"):
            print("-.-")
            lst[cont]="-.-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="l"):
            print(".-..")
            lst[cont]=".-.."
            cont=cont+1
            lst[cont]=" "
        elif (i=="m"):
            print("--")
            lst[cont]="--"
            cont=cont+1
            lst[cont]=" "
        elif (i=="n"):
            print("-.")
            lst[cont]="-."
            cont=cont+1
            lst[cont]=" "
        elif (i=="o"):
            print("---")
            lst[cont]="---"
            cont=cont+1
            lst[cont]=" "
        elif (i=="p"):
            print(".--.")
            lst[cont]=".--."
            cont=cont+1
            lst[cont]=" "
        elif (i=="q"):
            print("--.-")
            lst[cont]="--.-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="r"):
            print(".-.")
            lst[cont]=".-."
            cont=cont+1
            lst[cont]=" "
        elif (i=="s"):
            print("...")
            lst[cont]="..."
            cont=cont+1
            lst[cont]=" "
        elif (i=="t"):
            print("-")
            lst[cont]="-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="u"):
            print("..-")
            lst[cont]="..-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="v"):
            print("...-")
            lst[cont]="...-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="w"):
            print(".--")
            lst[cont]=".--"
            cont=cont+1
            lst[cont]=" "
        elif (i=="x"):
            print("-..-")
            lst[cont]="-..-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="y"):
            print("-.--")
            lst[cont]="-.--"
            cont=cont+1
            lst[cont]=" "
        elif (i=="z"):
            print("--..")
            lst[cont]="--.."
            cont=cont+1
            lst[cont]=" "
        elif (i=="1"):
            print(".----")
            lst[cont]=".----"
            cont=cont+1
            lst[cont]=" "
        elif (i=="2"):
            print("..---")
            lst[cont]="..---"
            cont=cont+1
            lst[cont]=" "
        elif (i=="3"):
            print("...--")
            lst[cont]="...--"
            cont=cont+1
            lst[cont]=" "
        elif (i=="4"):
            print("....-")
            lst[cont]="....-"
            cont=cont+1
            lst[cont]=" "
        elif (i=="5"):
            print(".....")
            lst[cont]="....."
            cont=cont+1
            lst[cont]=" "
        elif (i=="6"):
            print("-....")
            lst[cont]="-...."
            cont=cont+1
            lst[cont]=" "
        elif (i=="7"):
            print("--...")
            lst[cont]="--..."
            cont=cont+1
            lst[cont]=" "
        elif (i=="8"):
            print("---..")
            lst[cont]="---.."
            cont=cont+1
            lst[cont]=" "
        elif (i=="9"):
            print("----.")
            lst[cont]="----."
            cont=cont+1
            lst[cont]=" "
        elif (i=="0"):
            print("-----")
            lst[cont]="-----"
            cont=cont+1
            lst[cont]=" "
        elif (i==" "):
            print("/")
            lst[cont]="/"
            cont=cont+1
            lst[cont]=" "
        cont=cont+1
# Out:
# e
#
# e
# u
#
# s
# e
# i
#
# q
# u
# e
#
# t
# e
# m
#
# m
# o
# m
# e
# n
# t
# o
# s
#
# o
# n
# d
# e
#
# p
# a
# r
# e
# c
# e
#
# q
# u
# e
#
# a
#
# v
# i
# d
# a
#
# v
# a
# i
#
# t
# e
#
# e
# s
# m
# a
# g
# a
# r
#
# c
# o
# m
#
# e
# s
# s
# e
#
# p
# e
# s
# o
#
# m
# a
# s
#
# a
#
# d
# o
# r
#
# n
# a
# o
#
# p
# o
# d
# e
#
# t
# e
#
# d
# e
# i
# x
# a
# r
#
# d
# e
#
# l
# e
# m
# b
# r
# a
# r
#
# s
# o
# h
#
# q
# u
# a
# n
# d
# o
#
# e
# s
# t
# a
# m
# o
# s
#
# n
# o
#
# c
# h
# a
# o
#
# e
# h
#
# q
# u
# e
#
# p
# o
# d
# e
# m
# o
# s
#
# l
# e
# v
# a
# n
# t
# a
# r

# %% [markdown]
# Abaixo, temos a lista que armazena os dados traduzidos

# %%
print(lst)
# Out:
# ['e', ' ', 'e', 'u', ' ', 's', 'e', 'i', ' ', 'q', 'u', 'e', ' ', 't', 'e', 'm', ' ', 'm', 'o', 'm', 'e', 'n', 't', 'o', 's', ' ', 'o', 'n', 'd', 'e', ' ', 'p', 'a', 'r', 'e', 'c', 'e', ' ', 'q', 'u', 'e', ' ', 'a', ' ', 'v', 'i', 'd', 'a', ' ', 'v', 'a', 'i', ' ', 't', 'e', ' ', 'e', 's', 'm', 'a', 'g', 'a', 'r', ' ', 'c', 'o', 'm', ' ', 'e', 's', 's', 'e', ' ', 'p', 'e', 's', 'o', ' ', 'm', 'a', 's', ' ', 'a', ' ', 'd', 'o', 'r', ' ', 'n', 'a', 'o', ' ', 'p', 'o', 'd', 'e', ' ', 't', 'e', ' ', 'd', 'e', 'i', 'x', 'a', 'r', ' ', 'd', 'e', ' ', 'l', 'e', 'm', 'b', 'r', 'a', 'r', ' ', 's', 'o', 'h', ' ', 'q', 'u', 'a', 'n', 'd', 'o', ' ', 'e', 's', 't', 'a', 'm', 'o', 's', ' ', 'n', 'o', ' ', 'c', 'h', 'a', 'o', ' ', 'e', 'h', ' ', 'q', 'u', 'e', ' ', 'p', 'o', 'd', 'e', 'm', 'o', 's', ' ', 'l', 'e', 'v', 'a', 'n', 't', 'a', 'r']

# %% [markdown]
# Por fim, vamos exibir a frase traduzida

# %%
import sys
cont=0
for i in lst:
    print(lst[cont], end="")
    cont=cont+1
# Out:
# e eu sei que tem momentos onde parece que a vida vai te esmagar com esse peso mas a dor nao pode te deixar de lembrar soh quando estamos no chao eh que podemos levantar

# %% [markdown]
# Agora irei fazer uma classe contendo tudo feito acima

# %% [markdown]
# # Definição da Classe Morse

# %%
class Morse:
    def codificando(op,frase):       
        cont=0
        if(op==1):
            lst=frase.split()
            teste= frase.split()
            for i in teste:
                if (i==".-"):
                    lst[cont]="a"
                elif (i=="-..."):
                    lst[cont]="b"
                elif (i=="-.-."):
                    lst[cont]="c"
                elif (i=="-.."):
                    lst[cont]="d"
                elif (i=="."):
                    lst[cont]="e"
                elif (i=="..-."):
                    lst[cont]="f"
                elif (i=="--."):
                    lst[cont]="g"
                elif (i=="...."):
                    lst[cont]="h"
                elif (i==".."):
                    lst[cont]="i"
                elif (i==".---"):
                    lst[cont]="j"
                elif (i=="-.-"):
                    lst[cont]="k"
                elif (i==".-.."):
                    lst[cont]="l"
                elif (i=="--"):
                    lst[cont]="m"
                elif (i=="-."):
                    lst[cont]="n"
                elif (i=="---"):
                    lst[cont]="o"
                elif (i==".--."):
                    lst[cont]="p"
                elif (i=="--.-"):
                    lst[cont]="q"
                elif (i==".-."):
                    lst[cont]="r"
                elif (i=="..."):
                    lst[cont]="s"
                elif (i=="-"):
                    lst[cont]="t"
                elif (i=="..-"):
                    lst[cont]="u"
                elif (i=="...-"):
                    lst[cont]="v"
                elif (i==".--"):
                    lst[cont]="w"
                elif (i=="-..-"):
                    lst[cont]="x"
                elif (i=="-.--"):
                    lst[cont]="y"
                elif (i=="--.."):
                    lst[cont]="z"
                elif (i==".----"):
                    lst[cont]="1"
                elif (i=="..---"):
                    lst[cont]="2"
                elif (i=="...--"):
                    lst[cont]="3"
                elif (i=="....-"):
                    lst[cont]="4"
                elif (i=="....."):
                    lst[cont]="5"
                elif (i=="-...."):
                    lst[cont]="6"
                elif (i=="--..."):
                    lst[cont]="7"
                elif (i=="---.."):
                    lst[cont]="8"
                elif (i=="----."):
                    lst[cont]="9"
                elif (i=="-----"):
                    lst[cont]="0"
                elif (i=="/"):
                    lst[cont]=" "
                cont=cont+1
        elif(op==2):
            lst=list(frase)+list(frase)
            teste= list(frase)
            for i in teste:
                if (i=="a"):
                    lst[cont]=".-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="b"):
                    lst[cont]="-..."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="c"):
                    lst[cont]="-.-."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="d"):
                    lst[cont]="-.."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="e"):
                    lst[cont]="."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="f"):
                    lst[cont]="..-."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="g"):
                    lst[cont]="--."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="h"):
                    lst[cont]="...."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="i"):
                    lst[cont]=".."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="j"):
                    lst[cont]=".---"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="k"):
                    lst[cont]="-.-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="l"):
                    lst[cont]=".-.."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="m"):
                    lst[cont]="--"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="n"):
                    lst[cont]="-."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="o"):
                    lst[cont]="---"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="p"):
                    lst[cont]=".--."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="q"):
                    lst[cont]="--.-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="r"):
                    lst[cont]=".-."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="s"):
                    lst[cont]="..."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="t"):
                    lst[cont]="-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="u"):
                    lst[cont]="..-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="v"):
                    lst[cont]="...-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="w"):
                    lst[cont]=".--"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="x"):
                    lst[cont]="-..-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="y"):
                    lst[cont]="-.--"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="z"):
                    lst[cont]="--.."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="1"):
                    lst[cont]=".----"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="2"):
                    lst[cont]="..---"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="3"):
                    lst[cont]="...--"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="4"):
                    lst[cont]="....-"
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="5"):
                    lst[cont]="....."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="6"):
                    lst[cont]="-...."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="7"):
                    lst[cont]="--..."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="8"):
                    lst[cont]="---.."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="9"):
                    lst[cont]="----."
                    cont=cont+1
                    lst[cont]=" "
                elif (i=="0"):
                    lst[cont]="-----"
                    cont=cont+1
                    lst[cont]=" "
                elif (i==" "):
                    lst[cont]="/"
                    cont=cont+1
                    lst[cont]=" "
                cont=cont+1
        return lst
    def entrada(): 
        op = int(input("(1)Traduzir Código Morse ou (2)Codificar em Código Morse: "))
        if(op==1):
            print("Bora Traduzir")
        else:
            print("Bora Codificar")
            print(op)
        frase=input("Digite a frase: ")
        print("A frase é '"+ frase+ "'")
        frase=frase.lower()
        lst =Morse.codificando(op,frase)
        Morse.saida(lst)
    def saida(lst):
        import sys
        cont=0
        for i in lst:
            print(lst[cont], end="")
            cont=cont+1
Morse.entrada()
# Out:
# (1)Traduzir Código Morse ou (2)Codificar em Código Morse: 2
# Bora Codificar
# 2
# Digite a frase: gandalf o cinzento
# A frase é 'gandalf o cinzento'
# --. .- -. -.. .- .-.. ..-. / --- / -.-. .. -. --.. . -. - ---

# %% [markdown]
# ![isso%20%C3%A9%20tudo.jpg](attachment:isso%20%C3%A9%20tudo.jpg)

# %% [markdown]
# # Isso é tudo pessoal!
